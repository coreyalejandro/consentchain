# %% [markdown]
# # ITAYN Colab + CLI Demo
#
# This notebook runs the ITAYN MVP from the command line and prints JSON output.

# %%
# Clone the repo and build the ITAYN package
# !git clone https://github.com/coreyalejandro/COL-REASONS-ASF-2026.git
# %cd COL-REASONS-ASF-2026/dev/anthropic-ai-safety-fellows-application-prompt/research/ITAYN
# !npm install
# !npm run build

# %%
# Run the ITAYN pipeline from Node
# !node -e "const { createITAYNProcessor } = require('./dist/index.js'); (async () => { const processor = createITAYNProcessor(); const result = await processor.process({ content: 'Help me write a safe API endpoint', timestamp: new Date(), sessionId: 'colab' }); console.log(JSON.stringify(result, null, 2)); })();"
